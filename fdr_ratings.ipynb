# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
from sklearn.preprocessing import MinMaxScaler

# %%
# use option to display all columns of dataframe
pd.set_option('display.max_columns', None)

# %%
fpl = pd.read_csv('cleaned_data.csv')
fpl
# Out:
#        GW  round  fixture                              name position  \
# 0       1      1        6                        Alex Scott      MID
# 1       1      1        6  Carlos Miguel dos Santos Pereira       GK
# 2       1      1        2                 Tomiyasu Takehiro      DEF
# 3       1      1        8                   Malcolm Ebiowei      MID
# 4       1      1        5                 Ben Brereton Díaz      MID
# ...    ..    ...      ...                               ...      ...
# 15658  23     23      230                   Tawanda Chirewa      MID
# 15659  23     23      226                 Cameron Humphreys      MID
# 15660  23     23      223                      Ashley Young      DEF
# 15661  23     23      226                         Arne Slot       AM
# 15662  23     23      228                        James Bree      DEF
#
#                  team  opponent_team  starts  minutes  goals    xG  assists  \
# 0         Bournemouth             16       1       62      0  0.00        0
# 1       Nott'm Forest              3       0        0      0  0.00        0
# 2             Arsenal             20       0        0      0  0.00        0
# 3      Crystal Palace              4       0        0      0  0.00        0
# 4         Southampton             15       1       70      0  0.30        0
# ...               ...            ...     ...      ...    ...   ...      ...
# 15658          Wolves              1       0        0      0  0.00        0
# 15659         Ipswich             12       0        0      0  0.00        0
# 15660         Everton              5       0       12      0  0.00        0
# 15661       Liverpool             10       0        0      0  0.00        0
# 15662     Southampton             15       1       87      0  0.03        1
#
#          xA   xGI  GC   xGC  clean_sheets  own_goals  yellow_cards  red_cards  \
# 0      0.01  0.01   1  1.02             0          0             0          0
# 1      0.00  0.00   0  0.00             0          0             0          0
# 2      0.00  0.00   0  0.00             0          0             0          0
# 3      0.00  0.00   0  0.00             0          0             0          0
# 4      0.02  0.32   1  0.25             0          0             1          0
# ...     ...   ...  ..   ...           ...        ...           ...        ...
# 15658  0.00  0.00   0  0.00             0          0             0          0
# 15659  0.00  0.00   0  0.00             0          0             0          0
# 15660  0.00  0.00   0  0.06             0          0             0          0
# 15661  0.00  0.00   0  0.00             0          0             0          0
# 15662  0.14  0.17   3  2.66             0          0             0          0
#
#        penalties_missed  saves  penalties_saved  was_home  points  bonus  \
# 0                     0      0                0     False       2      0
# 1                     0      0                0      True       0      0
# 2                     0      0                0      True       0      0
# 3                     0      0                0     False       0      0
# 4                     0      0                0     False       1      0
# ...                 ...    ...              ...       ...     ...    ...
# 15658                 0      0                0      True       0      0
# 15659                 0      0                0     False       0      0
# 15660                 0      0                0     False       1      0
# 15661                 0      0                0      True      10      0
# 15662                 0      0                0      True       4      0
#
#             opponent
# 0      Nott'm Forest
# 1        Bournemouth
# 2             Wolves
# 3          Brentford
# 4          Newcastle
# ...              ...
# 15658        Arsenal
# 15659      Liverpool
# 15660       Brighton
# 15661        Ipswich
# 15662      Newcastle
#
# [15663 rows x 27 columns]

# %%
# create new columns for goals and expected goals home and away
fpl["goals_home"] = np.where(fpl["was_home"] == True, fpl["goals"], 0)
fpl["goals_away"] = np.where(fpl["was_home"] == False, fpl["goals"], 0)
fpl["xG_home"] = np.where(fpl["was_home"] == True, fpl["xG"], 0)
fpl["xG_away"] = np.where(fpl["was_home"] == False, fpl["xG"], 0)

# %%
gw_team_grouped = fpl.groupby(['GW', 'round', 'fixture', 'team', 'opponent']).aggregate({'goals': 'sum',
                                                                                        'xG': 'sum',
                                                                                        'was_home': 'max',
                                                                                        'goals_home' : 'sum',
                                                                                        'goals_away' : 'sum',
                                                                                        'xG_home' : 'sum',
                                                                                        'xG_away' : 'sum'}).reset_index()
gw_team_grouped
# Out:
#      GW  round  fixture         team   opponent  goals    xG  was_home  \
# 0     1      1        1       Fulham    Man Utd      0  0.44     False
# 1     1      1        1      Man Utd     Fulham      1  2.43      True
# 2     1      1        2      Arsenal     Wolves      2  1.26      True
# 3     1      1        2       Wolves    Arsenal      0  0.48     False
# 4     1      1        3     Brighton    Everton      3  1.44     False
# ..   ..    ...      ...          ...        ...    ...   ...       ...
# 453  23     23      228  Southampton  Newcastle      1  0.76      True
# 454  23     23      229    Leicester      Spurs      2  1.54     False
# 455  23     23      229        Spurs  Leicester      1  1.04      True
# 456  23     23      230      Arsenal     Wolves      1  1.00     False
# 457  23     23      230       Wolves    Arsenal      0  0.75      True
#
#      goals_home  goals_away  xG_home  xG_away
# 0             0           0     0.00     0.44
# 1             1           0     2.43     0.00
# 2             2           0     1.26     0.00
# 3             0           0     0.00     0.48
# 4             0           3     0.00     1.44
# ..          ...         ...      ...      ...
# 453           1           0     0.76     0.00
# 454           0           2     0.00     1.54
# 455           1           0     1.04     0.00
# 456           0           1     0.00     1.00
# 457           0           0     0.75     0.00
#
# [458 rows x 12 columns]

# %% [markdown]
# Join the grouped DataFrame with itself to get the stats of the opponent team such as goals conceded, expected goals conceded - do not sum these columns on a player basis as each player will have the total goals conceded and xGC they faced specifically and does not reflect the entire team, plus players who got subbed off early may have lower stats that what the entire team should get

# %%
# join the grouped df with itself to get the stats of the opponent team, which will give the goals conceded, xGC, etc. of the team in question
gw_team_stats_merged = pd.merge(gw_team_grouped,
                         gw_team_grouped,
                         how='left',
                         left_on=['GW', 'round', 'fixture', 'team'],
                         right_on=['GW', 'round', 'fixture', 'opponent'],
                         suffixes=('', '_opponent'))
gw_team_stats_merged
# Out:
#      GW  round  fixture         team   opponent  goals    xG  was_home  \
# 0     1      1        1       Fulham    Man Utd      0  0.44     False
# 1     1      1        1      Man Utd     Fulham      1  2.43      True
# 2     1      1        2      Arsenal     Wolves      2  1.26      True
# 3     1      1        2       Wolves    Arsenal      0  0.48     False
# 4     1      1        3     Brighton    Everton      3  1.44     False
# ..   ..    ...      ...          ...        ...    ...   ...       ...
# 453  23     23      228  Southampton  Newcastle      1  0.76      True
# 454  23     23      229    Leicester      Spurs      2  1.54     False
# 455  23     23      229        Spurs  Leicester      1  1.04      True
# 456  23     23      230      Arsenal     Wolves      1  1.00     False
# 457  23     23      230       Wolves    Arsenal      0  0.75      True
#
#      goals_home  goals_away  xG_home  xG_away team_opponent opponent_opponent  \
# 0             0           0     0.00     0.44       Man Utd            Fulham
# 1             1           0     2.43     0.00        Fulham           Man Utd
# 2             2           0     1.26     0.00        Wolves           Arsenal
# 3             0           0     0.00     0.48       Arsenal            Wolves
# 4             0           3     0.00     1.44       Everton          Brighton
# ..          ...         ...      ...      ...           ...               ...
# 453           1           0     0.76     0.00     Newcastle       Southampton
# 454           0           2     0.00     1.54         Spurs         Leicester
# 455           1           0     1.04     0.00     Leicester             Spurs
# 456           0           1     0.00     1.00        Wolves           Arsenal
# 457           0           0     0.75     0.00       Arsenal            Wolves
#
#      goals_opponent  xG_opponent  was_home_opponent  goals_home_opponent  \
# 0                 1         2.43               True                    1
# 1                 0         0.44              False                    0
# 2                 0         0.48              False                    0
# 3                 2         1.26               True                    2
# 4                 0         0.46               True                    0
# ..              ...          ...                ...                  ...
# 453               3         2.91              False                    0
# 454               1         1.04               True                    1
# 455               2         1.54              False                    0
# 456               0         0.75               True                    0
# 457               1         1.00              False                    0
#
#      goals_away_opponent  xG_home_opponent  xG_away_opponent
# 0                      0              2.43              0.00
# 1                      0              0.00              0.44
# 2                      0              0.00              0.48
# 3                      0              1.26              0.00
# 4                      0              0.46              0.00
# ..                   ...               ...               ...
# 453                    3              0.00              2.91
# 454                    0              1.04              0.00
# 455                    2              0.00              1.54
# 456                    0              0.75              0.00
# 457                    1              0.00              1.00
#
# [458 rows x 21 columns]

# %%
gw_team_stats_sliced = gw_team_stats_merged[['GW', 'round', 'fixture', 'team',
                                      'goals','xG', 'was_home', 'goals_home', 'goals_away', 'xG_home', 'xG_away',
                                      'goals_opponent', 'xG_opponent', 'goals_away_opponent', 'goals_home_opponent',
                                      'xG_away_opponent', 'xG_home_opponent', 'opponent']].copy()

team_stats_per_gw = gw_team_stats_sliced.rename(columns={'goals_opponent': 'GC',
                                                         'xG_opponent': 'xGC',
                                                         'goals_home_opponent' : 'GC_away',
                                                         'goals_away_opponent' : 'GC_home',
                                                         'xG_home_opponent' : 'xGC_away',
                                                         'xG_away_opponent' : 'xGC_home'})
team_stats_per_gw
# Out:
#      GW  round  fixture         team  goals    xG  was_home  goals_home  \
# 0     1      1        1       Fulham      0  0.44     False           0
# 1     1      1        1      Man Utd      1  2.43      True           1
# 2     1      1        2      Arsenal      2  1.26      True           2
# 3     1      1        2       Wolves      0  0.48     False           0
# 4     1      1        3     Brighton      3  1.44     False           0
# ..   ..    ...      ...          ...    ...   ...       ...         ...
# 453  23     23      228  Southampton      1  0.76      True           1
# 454  23     23      229    Leicester      2  1.54     False           0
# 455  23     23      229        Spurs      1  1.04      True           1
# 456  23     23      230      Arsenal      1  1.00     False           0
# 457  23     23      230       Wolves      0  0.75      True           0
#
#      goals_away  xG_home  xG_away  GC   xGC  GC_home  GC_away  xGC_home  \
# 0             0     0.00     0.44   1  2.43        0        1      0.00
# 1             0     2.43     0.00   0  0.44        0        0      0.44
# 2             0     1.26     0.00   0  0.48        0        0      0.48
# 3             0     0.00     0.48   2  1.26        0        2      0.00
# 4             3     0.00     1.44   0  0.46        0        0      0.00
# ..          ...      ...      ...  ..   ...      ...      ...       ...
# 453           0     0.76     0.00   3  2.91        3        0      2.91
# 454           2     0.00     1.54   1  1.04        0        1      0.00
# 455           0     1.04     0.00   2  1.54        2        0      1.54
# 456           1     0.00     1.00   0  0.75        0        0      0.00
# 457           0     0.75     0.00   1  1.00        1        0      1.00
#
#      xGC_away   opponent
# 0        2.43    Man Utd
# 1        0.00     Fulham
# 2        0.00     Wolves
# 3        1.26    Arsenal
# 4        0.46    Everton
# ..        ...        ...
# 453      0.00  Newcastle
# 454      1.04      Spurs
# 455      0.00  Leicester
# 456      0.75     Wolves
# 457      0.00    Arsenal
#
# [458 rows x 18 columns]

# %%
# create a new column for clean sheets
team_stats_per_gw['CS'] = np.where(team_stats_per_gw['GC'] == 0, 1, 0)
team_stats_per_gw['CS_home'] = np.where((team_stats_per_gw['GC'] == 0) & (team_stats_per_gw['was_home'] == True), 1, 0)
team_stats_per_gw['CS_away'] = np.where((team_stats_per_gw['GC'] == 0) & (team_stats_per_gw['was_home'] == False), 1, 0)

# create a new column for whether they won the match or not
team_stats_per_gw['match_won'] = np.where(team_stats_per_gw['goals'] > team_stats_per_gw['GC'], 1, 0)
#team_stats_per_gw['match_won_home'] = np.where((team_stats_per_gw['goals'] > team_stats_per_gw['GC']) & (team_stats_per_gw['was_home'] == True), 1, 0)
#team_stats_per_gw['match_won_away'] = np.where((team_stats_per_gw['goals'] > team_stats_per_gw['GC']) & (team_stats_per_gw['was_home'] == False), 1, 0)

# potentially use this
team_stats_per_gw['match_won_home'] = np.where((team_stats_per_gw['goals_home'] > team_stats_per_gw['GC_home']), 1, 0)
team_stats_per_gw['match_won_away'] = np.where((team_stats_per_gw['goals_away'] > team_stats_per_gw['GC_away']), 1, 0)
team_stats_per_gw
# Out:
#      GW  round  fixture         team  goals    xG  was_home  goals_home  \
# 0     1      1        1       Fulham      0  0.44     False           0
# 1     1      1        1      Man Utd      1  2.43      True           1
# 2     1      1        2      Arsenal      2  1.26      True           2
# 3     1      1        2       Wolves      0  0.48     False           0
# 4     1      1        3     Brighton      3  1.44     False           0
# ..   ..    ...      ...          ...    ...   ...       ...         ...
# 453  23     23      228  Southampton      1  0.76      True           1
# 454  23     23      229    Leicester      2  1.54     False           0
# 455  23     23      229        Spurs      1  1.04      True           1
# 456  23     23      230      Arsenal      1  1.00     False           0
# 457  23     23      230       Wolves      0  0.75      True           0
#
#      goals_away  xG_home  xG_away  GC   xGC  GC_home  GC_away  xGC_home  \
# 0             0     0.00     0.44   1  2.43        0        1      0.00
# 1             0     2.43     0.00   0  0.44        0        0      0.44
# 2             0     1.26     0.00   0  0.48        0        0      0.48
# 3             0     0.00     0.48   2  1.26        0        2      0.00
# 4             3     0.00     1.44   0  0.46        0        0      0.00
# ..          ...      ...      ...  ..   ...      ...      ...       ...
# 453           0     0.76     0.00   3  2.91        3        0      2.91
# 454           2     0.00     1.54   1  1.04        0        1      0.00
# 455           0     1.04     0.00   2  1.54        2        0      1.54
# 456           1     0.00     1.00   0  0.75        0        0      0.00
# 457           0     0.75     0.00   1  1.00        1        0      1.00
#
#      xGC_away   opponent  CS  CS_home  CS_away  match_won  match_won_home  \
# 0        2.43    Man Utd   0        0        0          0               0
# 1        0.00     Fulham   1        1        0          1               1
# 2        0.00     Wolves   1        1        0          1               1
# 3        1.26    Arsenal   0        0        0          0               0
# 4        0.46    Everton   1        0        1          1               0
# ..        ...        ...  ..      ...      ...        ...             ...
# 453      0.00  Newcastle   0        0        0          0               0
# 454      1.04      Spurs   0        0        0          1               0
# 455      0.00  Leicester   0        0        0          0               0
# 456      0.75     Wolves   1        0        1          1               0
# 457      0.00    Arsenal   0        0        0          0               0
#
#      match_won_away
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1
# ..              ...
# 453               0
# 454               1
# 455               0
# 456               1
# 457               0
#
# [458 rows x 24 columns]

# %%
team_total_stats = team_stats_per_gw.groupby('team').agg({'goals' : 'sum',
                                                         'xG' : 'sum',
                                                         'goals_home' : 'sum',
                                                         'xG_home' : 'sum',
                                                         'goals_away' : 'sum',
                                                         'xG_away' : 'sum',
                                                         'GC' : 'sum',
                                                         'xGC' : 'sum',
                                                         'GC_home' : 'sum',
                                                         'xGC_home' : 'sum',
                                                         'GC_away' : 'sum',
                                                         'xGC_away' : 'sum',
                                                         'CS' : 'sum',
                                                         'CS_home' : 'sum',
                                                         'CS_away' : 'sum',
                                                         'fixture' : 'count',
                                                         'was_home' : 'sum',
                                                         'match_won' : 'sum',
                                                         'match_won_home' : 'sum',
                                                         'match_won_away' : 'sum'}).reset_index()

team_total_stats = team_total_stats.rename(columns={'fixture' : 'games_played',
                                                    'was_home' : 'games_played_home',
                                                    'match_won' : 'games_won',
                                                    'match_won_home' : 'games_won_home',
                                                    'match_won_away' : 'games_won_away'})

team_total_stats['games_played_away'] = team_total_stats['games_played'] - team_total_stats['games_played_home']
team_total_stats
# Out:
#               team  goals     xG  goals_home  xG_home  goals_away  xG_away  \
# 0          Arsenal     42  38.99          20    21.43          22    17.56
# 1      Aston Villa     33  34.59          20    21.07          13    13.52
# 2      Bournemouth     41  44.34          17    21.21          24    23.13
# 3        Brentford     41  37.02          28    22.71          13    14.31
# 4         Brighton     34  31.95          13    16.55          21    15.40
# 5          Chelsea     45  47.21          20    23.36          25    23.85
# 6   Crystal Palace     25  31.87          11    16.86          14    15.01
# 7          Everton     16  22.38           9    12.03           7    10.35
# 8           Fulham     33  32.71          17    15.68          16    17.03
# 9          Ipswich     20  21.04           8    10.99          12    10.05
# 10       Leicester     25  23.33          11    12.08          14    11.25
# 11       Liverpool     54  51.86          24    23.76          30    28.10
# 12        Man City     46  44.50          23    24.52          23    19.98
# 13         Man Utd     27  32.53          16    19.12          11    13.41
# 14       Newcastle     40  40.54          19    19.31          21    21.23
# 15   Nott'm Forest     33  29.47          15    14.60          18    14.87
# 16     Southampton     15  23.31           8    12.78           7    10.53
# 17           Spurs     44  39.81          26    22.16          18    17.65
# 18        West Ham     27  31.89          15    17.13          12    14.76
# 19          Wolves     32  24.39          14    12.22          18    12.17
#
#     GC    xGC  GC_home  xGC_home  GC_away  xGC_away  CS  CS_home  CS_away  \
# 0   21  20.57        9      6.89       12     13.68   8        5        3
# 1   35  28.74       14      9.66       21     19.08   3        2        1
# 2   26  29.09        7     11.11       19     17.98   6        5        1
# 3   39  39.62       22     19.79       17     19.83   4        1        3
# 4   30  33.14       14     14.24       16     18.90   5        2        3
# 5   30  32.91       14     12.72       16     20.19   4        1        3
# 6   28  32.76       18     16.57       10     16.19   8        3        5
# 7   28  29.58       13     14.57       15     15.01   8        4        4
# 8   30  26.99       17     13.98       13     13.01   4        1        3
# 9   46  48.72       24     21.96       22     26.76   2        1        1
# 10  47  45.38       21     21.68       26     23.70   1        1        0
# 11  21  19.38        9      9.23       12     10.15   9        4        5
# 12  29  33.69       15     14.17       14     19.52   6        2        4
# 13  31  34.61       19     17.89       12     16.72   8        4        4
# 14  26  28.45       11     13.56       15     14.89   9        6        3
# 15  27  26.36       10     11.07       17     15.29   9        4        5
# 16  53  55.66       30     31.85       23     23.81   2        1        1
# 17  35  38.24       23     21.22       12     17.02   4        1        3
# 18  42  40.63       26     23.78       16     16.85   4        1        3
# 19  49  39.21       23     18.22       26     20.99   3        2        1
#
#     games_played  games_played_home  games_won  games_won_home  \
# 0             23                 11         12               6
# 1             23                 12         10               6
# 2             23                 11         11               6
# 3             23                 12          8               6
# 4             23                 11          8               3
# 5             23                 11         11               5
# 6             23                 12          7               3
# 7             22                 11          4               2
# 8             23                 12          8               4
# 9             23                 12          2               1
# 10            23                 12          4               2
# 11            22                 11         16               8
# 12            23                 11         12               7
# 13            23                 12          8               5
# 14            23                 11         12               6
# 15            23                 11         13               6
# 16            23                 11          1               1
# 17            23                 12          7               4
# 18            23                 12          7               4
# 19            23                 11          4               2
#
#     games_won_away  games_played_away
# 0                6                 12
# 1                4                 11
# 2                5                 12
# 3                2                 11
# 4                5                 12
# 5                6                 12
# 6                4                 11
# 7                2                 11
# 8                4                 11
# 9                1                 11
# 10               2                 11
# 11               8                 11
# 12               5                 12
# 13               3                 11
# 14               6                 12
# 15               7                 12
# 16               0                 12
# 17               3                 11
# 18               3                 11
# 19               2                 12

# %% [markdown]
# Need to make all stats on a **per game** basis as Everton and Liverpool have played 1 game less.
#
# Also need to make stats on a **per home/away game** basis so that it can be ranked fairly instead of doing total_home/total_away

# %%
stats_columns = list(team_total_stats.columns)
items_to_remove = ['team', 'games_played', 'games_played_home', 'games_played_away']

for item in items_to_remove:
    stats_columns.remove(item)
print(stats_columns)
# Out:
# ['goals', 'xG', 'goals_home', 'xG_home', 'goals_away', 'xG_away', 'GC', 'xGC', 'GC_home', 'xGC_home', 'GC_away', 'xGC_away', 'CS', 'CS_home', 'CS_away', 'games_won', 'games_won_home', 'games_won_away']

# %%
for column in stats_columns:
    if '_home' in column:
        team_total_stats[f'{column}_pg_home'] = round(team_total_stats[column] / team_total_stats['games_played_home'], 2)
    elif '_away' in column:
        team_total_stats[f'{column}_pg_away'] = round(team_total_stats[column] / team_total_stats['games_played_away'], 2)
    else:
        team_total_stats[f'{column}_pg'] = round(team_total_stats[column] / team_total_stats['games_played'], 2)
team_total_stats
# Out:
#               team  goals     xG  goals_home  xG_home  goals_away  xG_away  \
# 0          Arsenal     42  38.99          20    21.43          22    17.56
# 1      Aston Villa     33  34.59          20    21.07          13    13.52
# 2      Bournemouth     41  44.34          17    21.21          24    23.13
# 3        Brentford     41  37.02          28    22.71          13    14.31
# 4         Brighton     34  31.95          13    16.55          21    15.40
# 5          Chelsea     45  47.21          20    23.36          25    23.85
# 6   Crystal Palace     25  31.87          11    16.86          14    15.01
# 7          Everton     16  22.38           9    12.03           7    10.35
# 8           Fulham     33  32.71          17    15.68          16    17.03
# 9          Ipswich     20  21.04           8    10.99          12    10.05
# 10       Leicester     25  23.33          11    12.08          14    11.25
# 11       Liverpool     54  51.86          24    23.76          30    28.10
# 12        Man City     46  44.50          23    24.52          23    19.98
# 13         Man Utd     27  32.53          16    19.12          11    13.41
# 14       Newcastle     40  40.54          19    19.31          21    21.23
# 15   Nott'm Forest     33  29.47          15    14.60          18    14.87
# 16     Southampton     15  23.31           8    12.78           7    10.53
# 17           Spurs     44  39.81          26    22.16          18    17.65
# 18        West Ham     27  31.89          15    17.13          12    14.76
# 19          Wolves     32  24.39          14    12.22          18    12.17
#
#     GC    xGC  GC_home  xGC_home  GC_away  xGC_away  CS  CS_home  CS_away  \
# 0   21  20.57        9      6.89       12     13.68   8        5        3
# 1   35  28.74       14      9.66       21     19.08   3        2        1
# 2   26  29.09        7     11.11       19     17.98   6        5        1
# 3   39  39.62       22     19.79       17     19.83   4        1        3
# 4   30  33.14       14     14.24       16     18.90   5        2        3
# 5   30  32.91       14     12.72       16     20.19   4        1        3
# 6   28  32.76       18     16.57       10     16.19   8        3        5
# 7   28  29.58       13     14.57       15     15.01   8        4        4
# 8   30  26.99       17     13.98       13     13.01   4        1        3
# 9   46  48.72       24     21.96       22     26.76   2        1        1
# 10  47  45.38       21     21.68       26     23.70   1        1        0
# 11  21  19.38        9      9.23       12     10.15   9        4        5
# 12  29  33.69       15     14.17       14     19.52   6        2        4
# 13  31  34.61       19     17.89       12     16.72   8        4        4
# 14  26  28.45       11     13.56       15     14.89   9        6        3
# 15  27  26.36       10     11.07       17     15.29   9        4        5
# 16  53  55.66       30     31.85       23     23.81   2        1        1
# 17  35  38.24       23     21.22       12     17.02   4        1        3
# 18  42  40.63       26     23.78       16     16.85   4        1        3
# 19  49  39.21       23     18.22       26     20.99   3        2        1
#
#     games_played  games_played_home  games_won  games_won_home  \
# 0             23                 11         12               6
# 1             23                 12         10               6
# 2             23                 11         11               6
# 3             23                 12          8               6
# 4             23                 11          8               3
# 5             23                 11         11               5
# 6             23                 12          7               3
# 7             22                 11          4               2
# 8             23                 12          8               4
# 9             23                 12          2               1
# 10            23                 12          4               2
# 11            22                 11         16               8
# 12            23                 11         12               7
# 13            23                 12          8               5
# 14            23                 11         12               6
# 15            23                 11         13               6
# 16            23                 11          1               1
# 17            23                 12          7               4
# 18            23                 12          7               4
# 19            23                 11          4               2
#
#     games_won_away  games_played_away  goals_pg  xG_pg  goals_home_pg_home  \
# 0                6                 12      1.83   1.70                1.82
# 1                4                 11      1.43   1.50                1.67
# 2                5                 12      1.78   1.93                1.55
# 3                2                 11      1.78   1.61                2.33
# 4                5                 12      1.48   1.39                1.18
# 5                6                 12      1.96   2.05                1.82
# 6                4                 11      1.09   1.39                0.92
# 7                2                 11      0.73   1.02                0.82
# 8                4                 11      1.43   1.42                1.42
# 9                1                 11      0.87   0.91                0.67
# 10               2                 11      1.09   1.01                0.92
# 11               8                 11      2.45   2.36                2.18
# 12               5                 12      2.00   1.93                2.09
# 13               3                 11      1.17   1.41                1.33
# 14               6                 12      1.74   1.76                1.73
# 15               7                 12      1.43   1.28                1.36
# 16               0                 12      0.65   1.01                0.73
# 17               3                 11      1.91   1.73                2.17
# 18               3                 11      1.17   1.39                1.25
# 19               2                 12      1.39   1.06                1.27
#
#     xG_home_pg_home  goals_away_pg_away  xG_away_pg_away  GC_pg  xGC_pg  \
# 0              1.95                1.83             1.46   0.91    0.89
# 1              1.76                1.18             1.23   1.52    1.25
# 2              1.93                2.00             1.93   1.13    1.26
# 3              1.89                1.18             1.30   1.70    1.72
# 4              1.50                1.75             1.28   1.30    1.44
# 5              2.12                2.08             1.99   1.30    1.43
# 6              1.40                1.27             1.36   1.22    1.42
# 7              1.09                0.64             0.94   1.27    1.34
# 8              1.31                1.45             1.55   1.30    1.17
# 9              0.92                1.09             0.91   2.00    2.12
# 10             1.01                1.27             1.02   2.04    1.97
# 11             2.16                2.73             2.55   0.95    0.88
# 12             2.23                1.92             1.66   1.26    1.46
# 13             1.59                1.00             1.22   1.35    1.50
# 14             1.76                1.75             1.77   1.13    1.24
# 15             1.33                1.50             1.24   1.17    1.15
# 16             1.16                0.58             0.88   2.30    2.42
# 17             1.85                1.64             1.60   1.52    1.66
# 18             1.43                1.09             1.34   1.83    1.77
# 19             1.11                1.50             1.01   2.13    1.70
#
#     GC_home_pg_home  xGC_home_pg_home  GC_away_pg_away  xGC_away_pg_away  \
# 0              0.82              0.63             1.00              1.14
# 1              1.17              0.80             1.91              1.73
# 2              0.64              1.01             1.58              1.50
# 3              1.83              1.65             1.55              1.80
# 4              1.27              1.29             1.33              1.58
# 5              1.27              1.16             1.33              1.68
# 6              1.50              1.38             0.91              1.47
# 7              1.18              1.32             1.36              1.36
# 8              1.42              1.16             1.18              1.18
# 9              2.00              1.83             2.00              2.43
# 10             1.75              1.81             2.36              2.15
# 11             0.82              0.84             1.09              0.92
# 12             1.36              1.29             1.17              1.63
# 13             1.58              1.49             1.09              1.52
# 14             1.00              1.23             1.25              1.24
# 15             0.91              1.01             1.42              1.27
# 16             2.73              2.90             1.92              1.98
# 17             1.92              1.77             1.09              1.55
# 18             2.17              1.98             1.45              1.53
# 19             2.09              1.66             2.17              1.75
#
#     CS_pg  CS_home_pg_home  CS_away_pg_away  games_won_pg  \
# 0    0.35             0.45             0.25          0.52
# 1    0.13             0.17             0.09          0.43
# 2    0.26             0.45             0.08          0.48
# 3    0.17             0.08             0.27          0.35
# 4    0.22             0.18             0.25          0.35
# 5    0.17             0.09             0.25          0.48
# 6    0.35             0.25             0.45          0.30
# 7    0.36             0.36             0.36          0.18
# 8    0.17             0.08             0.27          0.35
# 9    0.09             0.08             0.09          0.09
# 10   0.04             0.08             0.00          0.17
# 11   0.41             0.36             0.45          0.73
# 12   0.26             0.18             0.33          0.52
# 13   0.35             0.33             0.36          0.35
# 14   0.39             0.55             0.25          0.52
# 15   0.39             0.36             0.42          0.57
# 16   0.09             0.09             0.08          0.04
# 17   0.17             0.08             0.27          0.30
# 18   0.17             0.08             0.27          0.30
# 19   0.13             0.18             0.08          0.17
#
#     games_won_home_pg_home  games_won_away_pg_away
# 0                     0.55                    0.50
# 1                     0.50                    0.36
# 2                     0.55                    0.42
# 3                     0.50                    0.18
# 4                     0.27                    0.42
# 5                     0.45                    0.50
# 6                     0.25                    0.36
# 7                     0.18                    0.18
# 8                     0.33                    0.36
# 9                     0.08                    0.09
# 10                    0.17                    0.18
# 11                    0.73                    0.73
# 12                    0.64                    0.42
# 13                    0.42                    0.27
# 14                    0.55                    0.50
# 15                    0.55                    0.58
# 16                    0.09                    0.00
# 17                    0.33                    0.27
# 18                    0.33                    0.27
# 19                    0.18                    0.17

# %%
# extract only the per game columns
per_game_totals_columns = [column for column in team_total_stats.columns if '_pg' in column]
per_game_totals_df = team_total_stats[per_game_totals_columns].copy()
per_game_totals_df = per_game_totals_df.set_index(team_total_stats['team'])
per_game_totals_df
# Out:
#                 goals_pg  xG_pg  goals_home_pg_home  xG_home_pg_home  \
# team
# Arsenal             1.83   1.70                1.82             1.95
# Aston Villa         1.43   1.50                1.67             1.76
# Bournemouth         1.78   1.93                1.55             1.93
# Brentford           1.78   1.61                2.33             1.89
# Brighton            1.48   1.39                1.18             1.50
# Chelsea             1.96   2.05                1.82             2.12
# Crystal Palace      1.09   1.39                0.92             1.40
# Everton             0.73   1.02                0.82             1.09
# Fulham              1.43   1.42                1.42             1.31
# Ipswich             0.87   0.91                0.67             0.92
# Leicester           1.09   1.01                0.92             1.01
# Liverpool           2.45   2.36                2.18             2.16
# Man City            2.00   1.93                2.09             2.23
# Man Utd             1.17   1.41                1.33             1.59
# Newcastle           1.74   1.76                1.73             1.76
# Nott'm Forest       1.43   1.28                1.36             1.33
# Southampton         0.65   1.01                0.73             1.16
# Spurs               1.91   1.73                2.17             1.85
# West Ham            1.17   1.39                1.25             1.43
# Wolves              1.39   1.06                1.27             1.11
#
#                 goals_away_pg_away  xG_away_pg_away  GC_pg  xGC_pg  \
# team
# Arsenal                       1.83             1.46   0.91    0.89
# Aston Villa                   1.18             1.23   1.52    1.25
# Bournemouth                   2.00             1.93   1.13    1.26
# Brentford                     1.18             1.30   1.70    1.72
# Brighton                      1.75             1.28   1.30    1.44
# Chelsea                       2.08             1.99   1.30    1.43
# Crystal Palace                1.27             1.36   1.22    1.42
# Everton                       0.64             0.94   1.27    1.34
# Fulham                        1.45             1.55   1.30    1.17
# Ipswich                       1.09             0.91   2.00    2.12
# Leicester                     1.27             1.02   2.04    1.97
# Liverpool                     2.73             2.55   0.95    0.88
# Man City                      1.92             1.66   1.26    1.46
# Man Utd                       1.00             1.22   1.35    1.50
# Newcastle                     1.75             1.77   1.13    1.24
# Nott'm Forest                 1.50             1.24   1.17    1.15
# Southampton                   0.58             0.88   2.30    2.42
# Spurs                         1.64             1.60   1.52    1.66
# West Ham                      1.09             1.34   1.83    1.77
# Wolves                        1.50             1.01   2.13    1.70
#
#                 GC_home_pg_home  xGC_home_pg_home  GC_away_pg_away  \
# team
# Arsenal                    0.82              0.63             1.00
# Aston Villa                1.17              0.80             1.91
# Bournemouth                0.64              1.01             1.58
# Brentford                  1.83              1.65             1.55
# Brighton                   1.27              1.29             1.33
# Chelsea                    1.27              1.16             1.33
# Crystal Palace             1.50              1.38             0.91
# Everton                    1.18              1.32             1.36
# Fulham                     1.42              1.16             1.18
# Ipswich                    2.00              1.83             2.00
# Leicester                  1.75              1.81             2.36
# Liverpool                  0.82              0.84             1.09
# Man City                   1.36              1.29             1.17
# Man Utd                    1.58              1.49             1.09
# Newcastle                  1.00              1.23             1.25
# Nott'm Forest              0.91              1.01             1.42
# Southampton                2.73              2.90             1.92
# Spurs                      1.92              1.77             1.09
# West Ham                   2.17              1.98             1.45
# Wolves                     2.09              1.66             2.17
#
#                 xGC_away_pg_away  CS_pg  CS_home_pg_home  CS_away_pg_away  \
# team
# Arsenal                     1.14   0.35             0.45             0.25
# Aston Villa                 1.73   0.13             0.17             0.09
# Bournemouth                 1.50   0.26             0.45             0.08
# Brentford                   1.80   0.17             0.08             0.27
# Brighton                    1.58   0.22             0.18             0.25
# Chelsea                     1.68   0.17             0.09             0.25
# Crystal Palace              1.47   0.35             0.25             0.45
# Everton                     1.36   0.36             0.36             0.36
# Fulham                      1.18   0.17             0.08             0.27
# Ipswich                     2.43   0.09             0.08             0.09
# Leicester                   2.15   0.04             0.08             0.00
# Liverpool                   0.92   0.41             0.36             0.45
# Man City                    1.63   0.26             0.18             0.33
# Man Utd                     1.52   0.35             0.33             0.36
# Newcastle                   1.24   0.39             0.55             0.25
# Nott'm Forest               1.27   0.39             0.36             0.42
# Southampton                 1.98   0.09             0.09             0.08
# Spurs                       1.55   0.17             0.08             0.27
# West Ham                    1.53   0.17             0.08             0.27
# Wolves                      1.75   0.13             0.18             0.08
#
#                 games_won_pg  games_won_home_pg_home  games_won_away_pg_away
# team
# Arsenal                 0.52                    0.55                    0.50
# Aston Villa             0.43                    0.50                    0.36
# Bournemouth             0.48                    0.55                    0.42
# Brentford               0.35                    0.50                    0.18
# Brighton                0.35                    0.27                    0.42
# Chelsea                 0.48                    0.45                    0.50
# Crystal Palace          0.30                    0.25                    0.36
# Everton                 0.18                    0.18                    0.18
# Fulham                  0.35                    0.33                    0.36
# Ipswich                 0.09                    0.08                    0.09
# Leicester               0.17                    0.17                    0.18
# Liverpool               0.73                    0.73                    0.73
# Man City                0.52                    0.64                    0.42
# Man Utd                 0.35                    0.42                    0.27
# Newcastle               0.52                    0.55                    0.50
# Nott'm Forest           0.57                    0.55                    0.58
# Southampton             0.04                    0.09                    0.00
# Spurs                   0.30                    0.33                    0.27
# West Ham                0.30                    0.33                    0.27
# Wolves                  0.17                    0.18                    0.17

# %% [markdown]
# ### Team Ranking and Fixture Ratings

# %% [markdown]
# #### Standardising the data

# %%
min_max_scaler = MinMaxScaler().fit(per_game_totals_df)
scaled = min_max_scaler.transform(per_game_totals_df)
team_stats_pg_scaled = pd.DataFrame(scaled, columns=per_game_totals_df.columns, index=per_game_totals_df.index)
team_stats_pg_scaled
# Out:
#                 goals_pg     xG_pg  goals_home_pg_home  xG_home_pg_home  \
# team
# Arsenal         0.655556  0.544828            0.692771         0.786260
# Aston Villa     0.433333  0.406897            0.602410         0.641221
# Bournemouth     0.627778  0.703448            0.530120         0.770992
# Brentford       0.627778  0.482759            1.000000         0.740458
# Brighton        0.461111  0.331034            0.307229         0.442748
# Chelsea         0.727778  0.786207            0.692771         0.916031
# Crystal Palace  0.244444  0.331034            0.150602         0.366412
# Everton         0.044444  0.075862            0.090361         0.129771
# Fulham          0.433333  0.351724            0.451807         0.297710
# Ipswich         0.122222  0.000000            0.000000         0.000000
# Leicester       0.244444  0.068966            0.150602         0.068702
# Liverpool       1.000000  1.000000            0.909639         0.946565
# Man City        0.750000  0.703448            0.855422         1.000000
# Man Utd         0.288889  0.344828            0.397590         0.511450
# Newcastle       0.605556  0.586207            0.638554         0.641221
# Nott'm Forest   0.433333  0.255172            0.415663         0.312977
# Southampton     0.000000  0.068966            0.036145         0.183206
# Spurs           0.700000  0.565517            0.903614         0.709924
# West Ham        0.288889  0.331034            0.349398         0.389313
# Wolves          0.411111  0.103448            0.361446         0.145038
#
#                 goals_away_pg_away  xG_away_pg_away     GC_pg    xGC_pg  \
# team
# Arsenal                   0.581395         0.347305  0.000000  0.006494
# Aston Villa               0.279070         0.209581  0.438849  0.240260
# Bournemouth               0.660465         0.628743  0.158273  0.246753
# Brentford                 0.279070         0.251497  0.568345  0.545455
# Brighton                  0.544186         0.239521  0.280576  0.363636
# Chelsea                   0.697674         0.664671  0.280576  0.357143
# Crystal Palace            0.320930         0.287425  0.223022  0.350649
# Everton                   0.027907         0.035928  0.258993  0.298701
# Fulham                    0.404651         0.401198  0.280576  0.188312
# Ipswich                   0.237209         0.017964  0.784173  0.805195
# Leicester                 0.320930         0.083832  0.812950  0.707792
# Liverpool                 1.000000         1.000000  0.028777  0.000000
# Man City                  0.623256         0.467066  0.251799  0.376623
# Man Utd                   0.195349         0.203593  0.316547  0.402597
# Newcastle                 0.544186         0.532934  0.158273  0.233766
# Nott'm Forest             0.427907         0.215569  0.187050  0.175325
# Southampton               0.000000         0.000000  1.000000  1.000000
# Spurs                     0.493023         0.431138  0.438849  0.506494
# West Ham                  0.237209         0.275449  0.661871  0.577922
# Wolves                    0.427907         0.077844  0.877698  0.532468
#
#                 GC_home_pg_home  xGC_home_pg_home  GC_away_pg_away  \
# team
# Arsenal                0.086124          0.000000         0.062069
# Aston Villa            0.253589          0.074890         0.689655
# Bournemouth            0.000000          0.167401         0.462069
# Brentford              0.569378          0.449339         0.441379
# Brighton               0.301435          0.290749         0.289655
# Chelsea                0.301435          0.233480         0.289655
# Crystal Palace         0.411483          0.330396         0.000000
# Everton                0.258373          0.303965         0.310345
# Fulham                 0.373206          0.233480         0.186207
# Ipswich                0.650718          0.528634         0.751724
# Leicester              0.531100          0.519824         1.000000
# Liverpool              0.086124          0.092511         0.124138
# Man City               0.344498          0.290749         0.179310
# Man Utd                0.449761          0.378855         0.124138
# Newcastle              0.172249          0.264317         0.234483
# Nott'm Forest          0.129187          0.167401         0.351724
# Southampton            1.000000          1.000000         0.696552
# Spurs                  0.612440          0.502203         0.124138
# West Ham               0.732057          0.594714         0.372414
# Wolves                 0.693780          0.453744         0.868966
#
#                 xGC_away_pg_away     CS_pg  CS_home_pg_home  CS_away_pg_away  \
# team
# Arsenal                 0.145695  0.837838         0.787234         0.555556
# Aston Villa             0.536424  0.243243         0.191489         0.200000
# Bournemouth             0.384106  0.594595         0.787234         0.177778
# Brentford               0.582781  0.351351         0.000000         0.600000
# Brighton                0.437086  0.486486         0.212766         0.555556
# Chelsea                 0.503311  0.351351         0.021277         0.555556
# Crystal Palace          0.364238  0.837838         0.361702         1.000000
# Everton                 0.291391  0.864865         0.595745         0.800000
# Fulham                  0.172185  0.351351         0.000000         0.600000
# Ipswich                 1.000000  0.135135         0.000000         0.200000
# Leicester               0.814570  0.000000         0.000000         0.000000
# Liverpool               0.000000  1.000000         0.595745         1.000000
# Man City                0.470199  0.594595         0.212766         0.733333
# Man Utd                 0.397351  0.837838         0.531915         0.800000
# Newcastle               0.211921  0.945946         1.000000         0.555556
# Nott'm Forest           0.231788  0.945946         0.595745         0.933333
# Southampton             0.701987  0.135135         0.021277         0.177778
# Spurs                   0.417219  0.351351         0.000000         0.600000
# West Ham                0.403974  0.351351         0.000000         0.600000
# Wolves                  0.549669  0.243243         0.212766         0.177778
#
#                 games_won_pg  games_won_home_pg_home  games_won_away_pg_away
# team
# Arsenal             0.695652                0.723077                0.684932
# Aston Villa         0.565217                0.646154                0.493151
# Bournemouth         0.637681                0.723077                0.575342
# Brentford           0.449275                0.646154                0.246575
# Brighton            0.449275                0.292308                0.575342
# Chelsea             0.637681                0.569231                0.684932
# Crystal Palace      0.376812                0.261538                0.493151
# Everton             0.202899                0.153846                0.246575
# Fulham              0.449275                0.384615                0.493151
# Ipswich             0.072464                0.000000                0.123288
# Leicester           0.188406                0.138462                0.246575
# Liverpool           1.000000                1.000000                1.000000
# Man City            0.695652                0.861538                0.575342
# Man Utd             0.449275                0.523077                0.369863
# Newcastle           0.695652                0.723077                0.684932
# Nott'm Forest       0.768116                0.723077                0.794521
# Southampton         0.000000                0.015385                0.000000
# Spurs               0.376812                0.384615                0.369863
# West Ham            0.376812                0.384615                0.369863
# Wolves              0.188406                0.153846                0.232877

# %% [markdown]
# Issue here is that for some stats it is better to have a higher value than others. So I am going to invert where necessary so the higher the value, the better

# %%
# need to invert the clean sheet columns so that higher values are better
stats_to_invert = ['GC_pg', 'xGC_pg', 'GC_home_pg_home', 'xGC_home_pg_home', 'GC_away_pg_away', 'xGC_away_pg_away']

for stat in stats_to_invert:
    team_stats_pg_scaled[stat] = 1 - team_stats_pg_scaled[stat]

team_stats_pg_scaled
# Out:
#                 goals_pg     xG_pg  goals_home_pg_home  xG_home_pg_home  \
# team
# Arsenal         0.655556  0.544828            0.692771         0.786260
# Aston Villa     0.433333  0.406897            0.602410         0.641221
# Bournemouth     0.627778  0.703448            0.530120         0.770992
# Brentford       0.627778  0.482759            1.000000         0.740458
# Brighton        0.461111  0.331034            0.307229         0.442748
# Chelsea         0.727778  0.786207            0.692771         0.916031
# Crystal Palace  0.244444  0.331034            0.150602         0.366412
# Everton         0.044444  0.075862            0.090361         0.129771
# Fulham          0.433333  0.351724            0.451807         0.297710
# Ipswich         0.122222  0.000000            0.000000         0.000000
# Leicester       0.244444  0.068966            0.150602         0.068702
# Liverpool       1.000000  1.000000            0.909639         0.946565
# Man City        0.750000  0.703448            0.855422         1.000000
# Man Utd         0.288889  0.344828            0.397590         0.511450
# Newcastle       0.605556  0.586207            0.638554         0.641221
# Nott'm Forest   0.433333  0.255172            0.415663         0.312977
# Southampton     0.000000  0.068966            0.036145         0.183206
# Spurs           0.700000  0.565517            0.903614         0.709924
# West Ham        0.288889  0.331034            0.349398         0.389313
# Wolves          0.411111  0.103448            0.361446         0.145038
#
#                 goals_away_pg_away  xG_away_pg_away         GC_pg    xGC_pg  \
# team
# Arsenal                   0.581395         0.347305  1.000000e+00  0.993506
# Aston Villa               0.279070         0.209581  5.611511e-01  0.759740
# Bournemouth               0.660465         0.628743  8.417266e-01  0.753247
# Brentford                 0.279070         0.251497  4.316547e-01  0.454545
# Brighton                  0.544186         0.239521  7.194245e-01  0.636364
# Chelsea                   0.697674         0.664671  7.194245e-01  0.642857
# Crystal Palace            0.320930         0.287425  7.769784e-01  0.649351
# Everton                   0.027907         0.035928  7.410072e-01  0.701299
# Fulham                    0.404651         0.401198  7.194245e-01  0.811688
# Ipswich                   0.237209         0.017964  2.158273e-01  0.194805
# Leicester                 0.320930         0.083832  1.870504e-01  0.292208
# Liverpool                 1.000000         1.000000  9.712230e-01  1.000000
# Man City                  0.623256         0.467066  7.482014e-01  0.623377
# Man Utd                   0.195349         0.203593  6.834532e-01  0.597403
# Newcastle                 0.544186         0.532934  8.417266e-01  0.766234
# Nott'm Forest             0.427907         0.215569  8.129496e-01  0.824675
# Southampton               0.000000         0.000000 -2.220446e-16  0.000000
# Spurs                     0.493023         0.431138  5.611511e-01  0.493506
# West Ham                  0.237209         0.275449  3.381295e-01  0.422078
# Wolves                    0.427907         0.077844  1.223022e-01  0.467532
#
#                 GC_home_pg_home  xGC_home_pg_home  GC_away_pg_away  \
# team
# Arsenal                0.913876          1.000000     9.379310e-01
# Aston Villa            0.746411          0.925110     3.103448e-01
# Bournemouth            1.000000          0.832599     5.379310e-01
# Brentford              0.430622          0.550661     5.586207e-01
# Brighton               0.698565          0.709251     7.103448e-01
# Chelsea                0.698565          0.766520     7.103448e-01
# Crystal Palace         0.588517          0.669604     1.000000e+00
# Everton                0.741627          0.696035     6.896552e-01
# Fulham                 0.626794          0.766520     8.137931e-01
# Ipswich                0.349282          0.471366     2.482759e-01
# Leicester              0.468900          0.480176    -2.220446e-16
# Liverpool              0.913876          0.907489     8.758621e-01
# Man City               0.655502          0.709251     8.206897e-01
# Man Utd                0.550239          0.621145     8.758621e-01
# Newcastle              0.827751          0.735683     7.655172e-01
# Nott'm Forest          0.870813          0.832599     6.482759e-01
# Southampton            0.000000          0.000000     3.034483e-01
# Spurs                  0.387560          0.497797     8.758621e-01
# West Ham               0.267943          0.405286     6.275862e-01
# Wolves                 0.306220          0.546256     1.310345e-01
#
#                 xGC_away_pg_away     CS_pg  CS_home_pg_home  CS_away_pg_away  \
# team
# Arsenal                 0.854305  0.837838         0.787234         0.555556
# Aston Villa             0.463576  0.243243         0.191489         0.200000
# Bournemouth             0.615894  0.594595         0.787234         0.177778
# Brentford               0.417219  0.351351         0.000000         0.600000
# Brighton                0.562914  0.486486         0.212766         0.555556
# Chelsea                 0.496689  0.351351         0.021277         0.555556
# Crystal Palace          0.635762  0.837838         0.361702         1.000000
# Everton                 0.708609  0.864865         0.595745         0.800000
# Fulham                  0.827815  0.351351         0.000000         0.600000
# Ipswich                 0.000000  0.135135         0.000000         0.200000
# Leicester               0.185430  0.000000         0.000000         0.000000
# Liverpool               1.000000  1.000000         0.595745         1.000000
# Man City                0.529801  0.594595         0.212766         0.733333
# Man Utd                 0.602649  0.837838         0.531915         0.800000
# Newcastle               0.788079  0.945946         1.000000         0.555556
# Nott'm Forest           0.768212  0.945946         0.595745         0.933333
# Southampton             0.298013  0.135135         0.021277         0.177778
# Spurs                   0.582781  0.351351         0.000000         0.600000
# West Ham                0.596026  0.351351         0.000000         0.600000
# Wolves                  0.450331  0.243243         0.212766         0.177778
#
#                 games_won_pg  games_won_home_pg_home  games_won_away_pg_away
# team
# Arsenal             0.695652                0.723077                0.684932
# Aston Villa         0.565217                0.646154                0.493151
# Bournemouth         0.637681                0.723077                0.575342
# Brentford           0.449275                0.646154                0.246575
# Brighton            0.449275                0.292308                0.575342
# Chelsea             0.637681                0.569231                0.684932
# Crystal Palace      0.376812                0.261538                0.493151
# Everton             0.202899                0.153846                0.246575
# Fulham              0.449275                0.384615                0.493151
# Ipswich             0.072464                0.000000                0.123288
# Leicester           0.188406                0.138462                0.246575
# Liverpool           1.000000                1.000000                1.000000
# Man City            0.695652                0.861538                0.575342
# Man Utd             0.449275                0.523077                0.369863
# Newcastle           0.695652                0.723077                0.684932
# Nott'm Forest       0.768116                0.723077                0.794521
# Southampton         0.000000                0.015385                0.000000
# Spurs               0.376812                0.384615                0.369863
# West Ham            0.376812                0.384615                0.369863
# Wolves              0.188406                0.153846                0.232877

# %% [markdown]
# #### Calculating FDR Ratings

# %%
def assign_fdr(value, df, column):
    max_value = df[column].max()
    min_value = df[column].min()
    normalised_score = (value - min_value) / (max_value - min_value)
    if normalised_score >= 0.9:
        return 10
    elif normalised_score >= 0.8:
        return 9
    elif normalised_score >= 0.7:
        return 8
    elif normalised_score >= 0.6:
        return 7
    elif normalised_score >= 0.5:
        return 6
    elif normalised_score >= 0.4:
        return 5
    elif normalised_score >= 0.3:
        return 4
    elif normalised_score >= 0.2:
        return 3
    elif normalised_score >= 0.1:
        return 2
    else:
        return 1

# %%
def fdr_calculator(stats_list, stat_type):
    
    df_filtered = team_stats_pg_scaled[stats_list].copy()
    df_filtered[f'combined_{stat_type}_score'] = df_filtered.sum(axis=1)
    df_filtered[f'combined_{stat_type}_score_home'] = df_filtered[[column for column in df_filtered.columns if '_home' in column]].sum(axis=1)
    df_filtered[f'combined_{stat_type}_score_away'] = df_filtered[[column for column in df_filtered.columns if '_away' in column]].sum(axis=1)

    df_filtered[f'total_{stat_type}_rank'] = df_filtered[f'combined_{stat_type}_score'].rank(method='min', ascending=False)
    df_filtered[f'home_{stat_type}_rank'] = df_filtered[f'combined_{stat_type}_score_home'].rank(method='min', ascending=False)
    df_filtered[f'away_{stat_type}_rank'] = df_filtered[f'combined_{stat_type}_score_away'].rank(method='min', ascending=False)

    df_filtered[f'FDR_{stat_type}_total'] = df_filtered[f'combined_{stat_type}_score'].apply(assign_fdr, df=df_filtered, column=f'combined_{stat_type}_score')
    df_filtered[f'FDR_{stat_type}_home'] = df_filtered[f'combined_{stat_type}_score_home'].apply(assign_fdr, df=df_filtered, column=f'combined_{stat_type}_score_home')
    df_filtered[f'FDR_{stat_type}_away'] = df_filtered[f'combined_{stat_type}_score_away'].apply(assign_fdr, df=df_filtered, column=f'combined_{stat_type}_score_away')

    return df_filtered[[f'total_{stat_type}_rank', f'FDR_{stat_type}_total', f'home_{stat_type}_rank', f'FDR_{stat_type}_home', f'away_{stat_type}_rank', f'FDR_{stat_type}_away']].sort_values(by=f'total_{stat_type}_rank')

# %%
total_stats_list = list(team_stats_pg_scaled.columns)

total_fdr_ratings = fdr_calculator(total_stats_list, 'total')
total_fdr_ratings
# Out:
#                 total_total_rank  FDR_total_total  home_total_rank  \
# team
# Liverpool                    1.0               10              1.0
# Arsenal                      2.0                8              2.0
# Newcastle                    3.0                8              4.0
# Man City                     4.0                7              5.0
# Bournemouth                  5.0                7              3.0
# Nott'm Forest                6.0                7              7.0
# Chelsea                      7.0                7              8.0
# Man Utd                      8.0                6             10.0
# Crystal Palace               9.0                6             15.0
# Spurs                       10.0                6             11.0
# Fulham                      11.0                6             13.0
# Brighton                    12.0                5             12.0
# Aston Villa                 13.0                5              6.0
# Brentford                   14.0                5              9.0
# Everton                     15.0                4             14.0
# West Ham                    16.0                4             16.0
# Wolves                      17.0                3             17.0
# Leicester                   18.0                2             18.0
# Ipswich                     19.0                1             19.0
# Southampton                 20.0                1             20.0
#
#                 FDR_total_home  away_total_rank  FDR_total_away
# team
# Liverpool                   10              1.0              10
# Arsenal                     10              2.0               7
# Newcastle                    9              3.0               7
# Man City                     9              6.0               6
# Bournemouth                  9             10.0               5
# Nott'm Forest                7              5.0               6
# Chelsea                      7              4.0               6
# Man Utd                      6             12.0               5
# Crystal Palace               5              7.0               6
# Spurs                        6              9.0               6
# Fulham                       5              8.0               6
# Brighton                     5             11.0               5
# Aston Villa                  7             16.0               3
# Brentford                    7             15.0               4
# Everton                      5             14.0               4
# West Ham                     4             13.0               4
# Wolves                       3             17.0               2
# Leicester                    3             18.0               1
# Ipswich                      2             19.0               1
# Southampton                  1             20.0               1

# %%
defensive_stats_list = ['GC_pg', 'xGC_pg', 'GC_home_pg_home', 'xGC_home_pg_home', 'GC_away_pg_away', 'xGC_away_pg_away', 'CS_pg', 'CS_home_pg_home', 'CS_away_pg_away']

defensive_fdr_ratings = fdr_calculator(defensive_stats_list, 'defensive')
defensive_fdr_ratings
# Out:
#                 total_defensive_rank  FDR_defensive_total  \
# team
# Liverpool                        1.0                   10
# Arsenal                          2.0                   10
# Nott'm Forest                    3.0                    9
# Newcastle                        4.0                    9
# Everton                          5.0                    8
# Crystal Palace                   6.0                    8
# Bournemouth                      7.0                    8
# Man Utd                          8.0                    8
# Man City                         9.0                    7
# Fulham                          10.0                    7
# Brighton                        11.0                    6
# Chelsea                         12.0                    6
# Aston Villa                     13.0                    5
# Spurs                           14.0                    5
# Brentford                       15.0                    4
# West Ham                        16.0                    4
# Wolves                          17.0                    3
# Ipswich                         18.0                    2
# Leicester                       19.0                    1
# Southampton                     20.0                    1
#
#                 home_defensive_rank  FDR_defensive_home  away_defensive_rank  \
# team
# Liverpool                       4.0                   9                  1.0
# Arsenal                         1.0                  10                  4.0
# Nott'm Forest                   5.0                   9                  3.0
# Newcastle                       3.0                  10                  8.0
# Everton                         6.0                   8                  7.0
# Crystal Palace                 10.0                   6                  2.0
# Bournemouth                     2.0                  10                 15.0
# Man Utd                         8.0                   7                  5.0
# Man City                       11.0                   6                  9.0
# Fulham                         13.0                   6                  6.0
# Brighton                        9.0                   6                 11.0
# Chelsea                        12.0                   6                 13.0
# Aston Villa                     7.0                   7                 16.0
# Spurs                          17.0                   4                 10.0
# Brentford                      15.0                   4                 14.0
# West Ham                       19.0                   3                 12.0
# Wolves                         14.0                   4                 18.0
# Ipswich                        18.0                   3                 19.0
# Leicester                      16.0                   4                 20.0
# Southampton                    20.0                   1                 17.0
#
#                 FDR_defensive_away
# team
# Liverpool                       10
# Arsenal                          9
# Nott'm Forest                    9
# Newcastle                        8
# Everton                          8
# Crystal Palace                  10
# Bournemouth                      5
# Man Utd                          8
# Man City                         8
# Fulham                           8
# Brighton                         7
# Chelsea                          6
# Aston Villa                      3
# Spurs                            7
# Brentford                        6
# West Ham                         7
# Wolves                           3
# Ipswich                          1
# Leicester                        1
# Southampton                      3

# %%
attacking_stats_list = ['goals_pg', 'xG_pg', 'goals_home_pg_home', 'xG_home_pg_home', 'goals_away_pg_away', 'xG_away_pg_away', 'games_won_pg', 'games_won_home_pg_home', 'games_won_away_pg_away']

attacking_fdr_ratings = fdr_calculator(attacking_stats_list, 'attacking')
attacking_fdr_ratings
# Out:
#                 total_attacking_rank  FDR_attacking_total  \
# team
# Liverpool                        1.0                   10
# Man City                         2.0                    8
# Chelsea                          3.0                    8
# Bournemouth                      4.0                    7
# Arsenal                          5.0                    7
# Newcastle                        6.0                    7
# Spurs                            7.0                    6
# Brentford                        8.0                    6
# Nott'm Forest                    9.0                    5
# Aston Villa                     10.0                    5
# Fulham                          11.0                    4
# Brighton                        12.0                    4
# Man Utd                         13.0                    4
# West Ham                        14.0                    4
# Crystal Palace                  15.0                    3
# Wolves                          16.0                    3
# Leicester                       17.0                    2
# Everton                         18.0                    1
# Ipswich                         19.0                    1
# Southampton                     20.0                    1
#
#                 home_attacking_rank  FDR_attacking_home  away_attacking_rank  \
# team
# Liverpool                       1.0                  10                  1.0
# Man City                        2.0                  10                  5.0
# Chelsea                         5.0                   8                  2.0
# Bournemouth                     6.0                   8                  3.0
# Arsenal                         4.0                   8                  6.0
# Newcastle                       7.0                   8                  4.0
# Spurs                           8.0                   7                 10.0
# Brentford                       3.0                   9                 14.0
# Nott'm Forest                  10.0                   6                  7.0
# Aston Villa                     9.0                   7                 12.0
# Fulham                         12.0                   4                  9.0
# Brighton                       14.0                   4                  8.0
# Man Utd                        11.0                   6                 15.0
# West Ham                       13.0                   4                 13.0
# Crystal Palace                 15.0                   3                 11.0
# Wolves                         16.0                   3                 16.0
# Leicester                      18.0                   2                 17.0
# Everton                        17.0                   2                 19.0
# Ipswich                        20.0                   1                 18.0
# Southampton                    19.0                   1                 20.0
#
#                 FDR_attacking_away
# team
# Liverpool                       10
# Man City                         6
# Chelsea                          7
# Bournemouth                      7
# Arsenal                          6
# Newcastle                        6
# Spurs                            5
# Brentford                        3
# Nott'm Forest                    5
# Aston Villa                      4
# Fulham                           5
# Brighton                         5
# Man Utd                          3
# West Ham                         3
# Crystal Palace                   4
# Wolves                           3
# Leicester                        3
# Everton                          2
# Ipswich                          2
# Southampton                      1

# %% [markdown]
# ^^ The ranking done above gives equal, maybe even more weight towards attack stats. I think it is actually better to give more weight to defensive stats because that's what you don't want to face in FPL really. Should make a ranking, FDR, etc. for defensive and attacking stats separately and rank based on this.

# %% [markdown]
# Can probably make a function for this where I insert a list of columns and get a ranking.
#
# Can then replace this for defensive stats, attacking stats both in total, at home, and away

# %% [markdown]
# Once this is done, give all the teams a defensive scoring for their home and away fixture
#
# Make it a mix of total rank and home/away rank because I don't want the fixture rank solely on their home/away performance, it should take total too
#
# So do a weighting - like 70% of total + 30^ of respective home/away fixture rank

# %% [markdown]
# Could I maybe do total_FDR + home/away FDR divided by 2? It seems to work okay or 70% : 30%

# %%
# Function to calculate weighted FDR
def weighted_fdr(row, weight_total, weight_home_away):
    """
    Function to calculate weighted FDR for a team
    """
    if weight_total + weight_home_away != 1:
        raise ValueError('Total weight must add to 1')
    
    else:
        row['weighted_home_FDR'] = round(weight_total * row['total_FDR'] + weight_home_away * row['home_FDR'], 1)
        row['weighted_away_FDR'] = round(weight_total * row['total_FDR'] + weight_home_away * row['away_FDR'], 1)

    return row

# %%
#z_df.apply(weighted_fdr, axis=1, weight_total=0.7, weight_home_away=0.3)[['total_FDR', 'home_FDR', 'away_FDR', 'weighted_home_FDR', 'weighted_away_FDR']].sort_values(by='total_FDR', ascending=False)

# %%
fixtures = []
for team in team_total_stats['team']:
    fixtures.append(team + "_home")
    fixtures.append(team + "_away")

df = pd.DataFrame(index=fixtures, columns=["FDR"])
df
# Out:
#                      FDR
# Arsenal_home         NaN
# Arsenal_away         NaN
# Aston Villa_home     NaN
# Aston Villa_away     NaN
# Bournemouth_home     NaN
# Bournemouth_away     NaN
# Brentford_home       NaN
# Brentford_away       NaN
# Brighton_home        NaN
# Brighton_away        NaN
# Chelsea_home         NaN
# Chelsea_away         NaN
# Crystal Palace_home  NaN
# Crystal Palace_away  NaN
# Everton_home         NaN
# Everton_away         NaN
# Fulham_home          NaN
# Fulham_away          NaN
# Ipswich_home         NaN
# Ipswich_away         NaN
# Leicester_home       NaN
# Leicester_away       NaN
# Liverpool_home       NaN
# Liverpool_away       NaN
# Man City_home        NaN
# Man City_away        NaN
# Man Utd_home         NaN
# Man Utd_away         NaN
# Newcastle_home       NaN
# Newcastle_away       NaN
# Nott'm Forest_home   NaN
# Nott'm Forest_away   NaN
# Southampton_home     NaN
# Southampton_away     NaN
# Spurs_home           NaN
# Spurs_away           NaN
# West Ham_home        NaN
# West Ham_away        NaN
# Wolves_home          NaN
# Wolves_away          NaN
